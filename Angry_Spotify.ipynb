# %% [markdown]
# ## Angry Spotify
# #### Background
# The goal of this project is to observe changes in the emotion of anger throughout the decade in popular music. The data I will be using are the "All Out XXs" playlists from Spotify, which feature popular music for that respective decade. This project was heavily inspired by [this project](https://towardsdatascience.com/angriest-death-grips-data-song-anger-code-through-r-ded3aa2fe844) by Evan Oppenheimer, and I utilize his method of classifying anger.
#
# #### Classifying "anger"

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json

# %%
# grab credentials for API authorization as well as all the playlists we will be using for the analysis (All out XXs playlists)
credentials = json.load(open('Authorization.json'))
client_id = credentials['client_id']
client_secret = credentials['client_secret']

playlists = json.load(open('Playlists.json'))
#playlist_uri = playlists[playlist_index]['uri']
#like = playlists[playlist_index]['like']

# %%
# Now we want to connect to the Genius API so we can grab lyrics, and then scrape the webpage for the lyrics
import requests
import requests
from bs4 import BeautifulSoup as bs
from pprint import pprint

def extract_lyrics(song_title, artist_name):
    # setup connection to Genius API
    base_url = "https://api.genius.com"
    headers = {'Authorization' : 'Bearer ' + 'ZbJWwJ1ewLAI_aPZqY_MCD6WDtmg6du-2dsLWWUT7kA6ggprN54e2m8Pd-uPHrWC'}
    search_url = base_url + '/search'
    data = {'q' : song_title + ' ' + artist_name}
    response = requests.get(search_url, data=data, headers=headers, timeout=None)
    json = response.json()
    remote_song_info = None

    # grab song info
    for hit in json['response']['hits']:
        if artist_name.lower() in hit['result']['primary_artist']['name'].lower():
            remote_song_info = hit
            break

    # Grab the URL from the song info as it's all we need
    song_url = None
    if remote_song_info:
        song_url = remote_song_info['result']['url']

    # now we scrape the lyrics webpage and store each line in a list
    r = requests.get(song_url)
    soup = bs(r.content, 'html')
    lyrics = [i for j in [[line for line in verse.stripped_strings] for verse in soup.select('[data-scrolltrigger-pin]')] for i in j]

    return lyrics

# %%
# Now we want to take these lyrics and split them by whitespace and find the frequency of angry words using the lexicon
# First let's load in the data, it's pretty big!
import pandas as pd
lexicon = pd.read_excel('/home/akagi/Documents/Projects/Angry Spotify/NRC-Emotion-Lexicon/NRC-Emotion-Lexicon-v0.92/NRC-Emotion-Lexicon-v0.92-In105Languages-Nov2017Translations.xlsx')

# %%
# now let's set up the lexicon data
# contains word and whether it is classified as angry
english_and_angry = [(x,y) for x,y in zip(lexicon['English (en)'], lexicon['Anger'])]

# %%
# list of all angry english words
angry_words = [x for x,y in english_and_angry if y == 1]

# %%
# Now we want to calculate the number of angry words
import re
def calc_angry_words(lyrics):
    # the lyrics will be fed as outputted extract_lyrics(), which returns a list containing each verse as an element
    # thus we want to take each verse and break it up into it's individual words and throw this into a list
    angry_count = 0
    for verse in lyrics:
        v_list = re.split('; |, ', verse)
        for word in v_list:
            if word in angry_words:
                angry_count += 1

    # number of angry words in a song
    return angry_count

# %%
# Now it's time to extract the songs from spotify's playlists and gather information about the valence
# we will construct an anger index similar to the death grips analysis
# We want high sonic anger index = sqrt((1-valence)*energy) as well as a high lyrical anger index  = sqrt(angry words / duration)
# thus our total angry index = sonic anger index + lyrical anger index
# We will then take the average (or median) of songs by decade for this index

# %%
# Construct Spotify API
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Grab tracks from a playlist
def get_playlist_tracks(username,playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
# now we begin gathering the data for each playlist
import numpy as np
import math
from itertools import chain

username = 'Spotify'
sonic_anger_indices = {}
decade_id = 50
for playlist in playlists:
    uri = playlist['uri']
    playlist_id = uri.split(':')[2]
    playlist_tracks_data = get_playlist_tracks(username, playlist_id)
    playlist_tracks_id = []
    playlist_tracks_titles = []
    playlist_tracks_first_artists = []

    # gather IDs, name, title for the tracks in the playlist
    for track in playlist_tracks_data:
        playlist_tracks_id.append(track['track']['id'])
        playlist_tracks_first_artists.append(track['track']['artists'][0])

        # Clean song names for proper search
        song_name = track['track']['name']
        song_name = song_name.replace("&", "and")
        song_name = song_name.replace("'", "\'")
        song_name = re.split(r'\s+(?:-\s+|\()', song_name)
        song_name = song_name[0]
        playlist_tracks_titles.append(song_name)

    artists = [elem['name'].replace("&", "and").replace("'", "\''") for elem in playlist_tracks_first_artists]

    # gather audio analysis
    features_list = []
    for id in playlist_tracks_id:
        try:
            features = sp.audio_features(id)
            features_list.append(features)
        except:
            print("Track ID not available")

    features_df = pd.DataFrame(data=list(chain.from_iterable(features_list)), columns=features[0].keys())
    features_df = features_df[['id',
                           'danceability', 'energy', 'key', 'loudness',
                           'mode', 'acousticness', 'instrumentalness',
                           'liveness', 'valence', 'tempo',
                           'duration_ms', 'time_signature']]
    
    valence = features_df[['valence']]
    energy = features_df[['energy']]
    duration = features_df[['duration_ms']]

    # now we calculate the sonic anger index
    s_ang = math.sqrt((1-float(valence.mean()))*float(energy.mean()))

    # now let's calculate the lyrical anger index
    total_angry_words = 0
    for title, artist in zip(playlist_tracks_titles, artists):
        try:
            lyrics = extract_lyrics(title, artist)
            num_angry_words = calc_angry_words(lyrics)
            total_angry_words += num_angry_words
        except:
            print("No results for artist %s with song %s" % (artist, title))
            print("Empty URL, skipping")

    try:
        l_ang = math.sqrt(total_angry_words / float(duration.sum()))
    except:
        print("duration missing, skipping")

    # just aggregate together
    total_ang = s_ang + l_ang

    decade = str(decade_id) + 's'
    sonic_anger_indices[decade] = total_ang
    decade_id += 10
# Out:
# Track ID not available
# No results for artist Frank Sinatra with song I've Got You Under My Skin
# Empty URL, skipping
# No results for artist The Platters with song Smoke Gets In Your Eyes
# Empty URL, skipping
# No results for artist Ray Charles with song What'd I Say, Pt. 1 and 2
# Empty URL, skipping
# No results for artist Ella Fitzgerald with song Dream A Little Dream Of Me
# Empty URL, skipping
# No results for artist Buddy Holly with song That'll Be The Day
# Empty URL, skipping
# No results for artist Bobby Darin with song Mack the Knife
# Empty URL, skipping
# No results for artist Fats Domino with song Blueberry Hill
# Empty URL, skipping
# No results for artist Dean Martin with song That's Amore
# Empty URL, skipping
# No results for artist The Everly Brothers with song All I Have to Do Is Dream
# Empty URL, skipping
# No results for artist Chuck Berry with song Johnny B. Goode
# Empty URL, skipping
# No results for artist Phil Phillips with song Sea Of Love
# Empty URL, skipping
# No results for artist Ray Charles with song I Can't Stop Loving You
# Empty URL, skipping
# No results for artist Sarah Vaughan with song Broken Hearted Melody
# Empty URL, skipping
# No results for artist Bobby Darin with song Beyond the Sea
# Empty URL, skipping
# No results for artist Fats Domino with song Jambalaya
# Empty URL, skipping
# Empty URL, skipping
# No results for artist Sam Cooke with song Cupid
# Empty URL, skipping
# No results for artist Glen Campbell with song Wichita Lineman
# Empty URL, skipping
# No results for artist The 5th Dimension with song Aquarius/Let The Sunshine In
# Empty URL, skipping
# No results for artist The Mamas and The Papas with song Monday, Monday
# Empty URL, skipping
# No results for artist Wilson Pickett with song In the Midnight Hour
# Empty URL, skipping
# No results for artist The Beatles with song All You Need Is Love
# Empty URL, skipping
# No results for artist Dionne Warwick with song Do You Know the Way to San Jose
# Empty URL, skipping
# No results for artist Bob Dylan with song Lay, Lady, Lay
# Empty URL, skipping
# No results for artist Sam Cooke with song Twistin' the Night Away
# Empty URL, skipping
# No results for artist Tom Jones with song It's Not Unusual
# Empty URL, skipping
# No results for artist Bee Gees with song Massachusetts
# Empty URL, skipping
# No results for artist The Band with song The Weight
# Empty URL, skipping
# No results for artist Dusty Springfield with song You Don't Have To Say You Love Me
# Empty URL, skipping
# No results for artist Small Faces with song Itchycoo Park
# Empty URL, skipping
# No results for artist Four Tops with song Baby I Need Your Loving
# Empty URL, skipping
# No results for artist The Chiffons with song One Fine Day
# Empty URL, skipping
# No results for artist Sam Cooke with song Another Saturday Night
# Empty URL, skipping
# No results for artist Joni Mitchell with song Both Sides Now
# Empty URL, skipping
# No results for artist Aretha Franklin with song Respect
# Empty URL, skipping
# No results for artist The Supremes with song Baby Love
# Empty URL, skipping
# No results for artist The Mamas and The Papas with song California Dreamin'
# Empty URL, skipping
# No results for artist Gerry and The Pacemakers with song Ferry Cross the Mersey
# Empty URL, skipping
# No results for artist Patsy Cline with song Crazy
# Empty URL, skipping
# No results for artist Wilson Pickett with song Mustang Sally
# Empty URL, skipping
# No results for artist Andy Williams with song Moon River
# Empty URL, skipping
# No results for artist The Archies with song Sugar Sugar
# Empty URL, skipping
# No results for artist The Byrds with song Mr. Tambourine Man
# Empty URL, skipping
# No results for artist Diana Ross and The Supremes with song Someday We'll Be Together
# Empty URL, skipping
# No results for artist Aretha Franklin with song (You Make Me Feel Like) A Natural Woman
# Empty URL, skipping
# No results for artist Them with song Gloria
# Empty URL, skipping
# No results for artist Herb Alpert and The Tijuana Brass with song This Guy's In Love With You
# Empty URL, skipping
# No results for artist Frank Sinatra with song Somethin' Stupid
# Empty URL, skipping
# No results for artist Etta James with song At Last
# Empty URL, skipping
# No results for artist Jimmy Ruffin with song What Becomes Of The Brokenhearted
# Empty URL, skipping
# No results for artist Little Eva with song The Loco-Motion
# Empty URL, skipping
# No results for artist The Isley Brothers with song This Old Heart Of Mine
# Empty URL, skipping
# No results for artist The Ronettes with song Be My Baby
# Empty URL, skipping
# No results for artist The Monkees with song Last Train to Clarksville
# Empty URL, skipping
# No results for artist Smokey Robinson and The Miracles with song The Tracks Of My Tears
# Empty URL, skipping
# No results for artist The Shirelles with song Will You Love Me Tomorrow
# Empty URL, skipping
# No results for artist Marvin Gaye with song It Takes Two
# Empty URL, skipping
# No results for artist The Byrds with song Turn! Turn! Turn!
# Empty URL, skipping
# No results for artist The Rolling Stones with song Honky Tonk Women
# Empty URL, skipping
# No results for artist Simon and Garfunkel with song America
# Empty URL, skipping
# No results for artist Bob Dylan with song Like a Rolling Stone
# Empty URL, skipping
# No results for artist The Seekers with song Georgy Girl
# Empty URL, skipping
# No results for artist Smokey Robinson and The Miracles with song The Tears Of A Clown
# Empty URL, skipping
# No results for artist Ike and Tina Turner with song River Deep
# Empty URL, skipping
# No results for artist Creedence Clearwater Revival with song Bad Moon Rising
# Empty URL, skipping
# No results for artist Fontella Bass with song Rescue Me
# Empty URL, skipping
# No results for artist Tom Jones with song Delilah
# Empty URL, skipping
# No results for artist Stevie Wonder with song Yester-Me, Yester-You, Yesterday
# Empty URL, skipping
# No results for artist The Dixie Cups with song Chapel of Love
# Empty URL, skipping
# No results for artist Diana Ross and The Supremes with song Reflections
# Empty URL, skipping
# No results for artist Eddie Floyd with song Knock on Wood
# Empty URL, skipping
# No results for artist The Beatles with song Twist And Shout
# Empty URL, skipping
# No results for artist Ray Charles with song Georgia on My Mind
# Empty URL, skipping
# No results for artist The Lovin'' Spoonful with song Do You Believe in Magic?
# Empty URL, skipping
# No results for artist Judy Collins with song Both Sides Now
# Empty URL, skipping
# No results for artist The Kinks with song Waterloo Sunset
# Empty URL, skipping
# No results for artist Neil Diamond with song Sweet Caroline
# Empty URL, skipping
# No results for artist The Rolling Stones with song Jumpin' Jack Flash
# Empty URL, skipping
# No results for artist The Supremes with song Stop! In The Name Of Love
# Empty URL, skipping
# No results for artist The Everly Brothers with song Cathy's Clown
# Empty URL, skipping
# No results for artist The Beatles with song Can't Buy Me Love
# Empty URL, skipping
# No results for artist The Troggs with song Wild Thing
# Empty URL, skipping
# No results for artist Procol Harum with song A Whiter Shade Of Pale
# Empty URL, skipping
# No results for artist The Foundations with song Build Me Up Buttercup
# Empty URL, skipping
# No results for artist The Searchers with song Needles and Pins
# Empty URL, skipping
# No results for artist The Easybeats with song Friday On My Mind
# Empty URL, skipping
# No results for artist Manfred Mann with song Do Wah Diddy Diddy
# Empty URL, skipping
# No results for artist The Kingsmen with song Louie Louie
# Empty URL, skipping
# No results for artist Johnny Cash with song I Walk the Line
# Empty URL, skipping
# No results for artist Otis Redding with song Hard to Handle
# Empty URL, skipping
# No results for artist Peter Sarstedt with song Where Do You Go To
# Empty URL, skipping
# No results for artist The Everly Brothers with song Crying in the Rain
# Empty URL, skipping
# No results for artist The Lovin'' Spoonful with song Summer in the City
# Empty URL, skipping
# No results for artist The Drifters with song Saturday Night at the Movies
# Empty URL, skipping
# No results for artist Fleetwood Mac with song Albatross
# Empty URL, skipping
# No results for artist Bobbie Gentry with song Ode To Billie Joe
# Empty URL, skipping
# No results for artist Johnny Cash with song Ring of Fire
# Empty URL, skipping
# No results for artist The Cascades with song Rhythm of the Rain
# Empty URL, skipping
# No results for artist Sam and Dave with song Soul Man
# Empty URL, skipping
# No results for artist The Crystals with song Then He Kissed Me
# Empty URL, skipping
# No results for artist Roberta Flack with song The First Time Ever I Saw Your Face
# Empty URL, skipping
# No results for artist Erma Franklin with song Piece of My Heart
# Empty URL, skipping
# No results for artist Ricky Nelson with song Hello Mary Lou, Goodbye Heart
# Empty URL, skipping
# Empty URL, skipping
# No results for artist Peter Gabriel with song Solsbury Hill
# Empty URL, skipping
# No results for artist ABBA with song Take A Chance On Me
# Empty URL, skipping
# No results for artist Billy Joel with song Just the Way You Are
# Empty URL, skipping
# No results for artist John Denver with song Annie's Song
# Empty URL, skipping
# No results for artist The Doobie Brothers with song What a Fool Believes
# Empty URL, skipping
# No results for artist Elton John with song Goodbye Yellow Brick Road
# Empty URL, skipping
# No results for artist Simon and Garfunkel with song Bridge Over Troubled Water
# Empty URL, skipping
# No results for artist Bread with song Everything I Own
# Empty URL, skipping
# No results for artist Billy Joel with song Piano Man
# Empty URL, skipping
# No results for artist Paul Simon with song 50 Ways to Leave Your Lover
# Empty URL, skipping
# No results for artist The Hollies with song The Air That I Breathe
# Empty URL, skipping
# No results for artist James Taylor with song Fire and Rain
# Empty URL, skipping
# No results for artist Wings with song Silly Love Songs
# Empty URL, skipping
# No results for artist Elton John with song Daniel
# Empty URL, skipping
# No results for artist Neil Diamond with song Forever In Blue Jeans
# Empty URL, skipping
# No results for artist Joni Mitchell with song Big Yellow Taxi
# Empty URL, skipping
# No results for artist Bruce Springsteen with song Born to Run
# Empty URL, skipping
# No results for artist Marvin Hamlisch with song Nobody Does It Better
# Empty URL, skipping
# No results for artist Carole King with song It's Too Late
# Empty URL, skipping
# No results for artist Albert Hammond with song It Never Rains in Southern California
# Empty URL, skipping
# No results for artist Elton John with song Crocodile Rock
# Empty URL, skipping
# No results for artist Boston with song More Than a Feeling
# Empty URL, skipping
# No results for artist Don McLean with song Vincent
# Empty URL, skipping
# No results for artist Van Morrison with song Into the Mystic
# Empty URL, skipping
# No results for artist Neil Diamond with song I Am...I Said
# Empty URL, skipping
# No results for artist The Kinks with song Lola
# Empty URL, skipping
# No results for artist Captain and Tennille with song Love Will Keep Us Together
# Empty URL, skipping
# No results for artist Dolly Parton with song Jolene
# Empty URL, skipping
# No results for artist Hues Corporation with song Rock the Boat
# Empty URL, skipping
# No results for artist Neil Diamond with song Cracklin' Rosie
# Empty URL, skipping
# No results for artist Stevie Wonder with song Signed, Sealed, Delivered
# Empty URL, skipping
# No results for artist Simon and Garfunkel with song The Boxer
# Empty URL, skipping
# No results for artist Wings with song Band On The Run
# Empty URL, skipping
# No results for artist Janis Joplin with song Me and Bobby McGee
# Empty URL, skipping
# No results for artist Neil Sedaka with song Laughter In The Rain
# Empty URL, skipping
# No results for artist Cheap Trick with song I Want You to Want Me
# Empty URL, skipping
# No results for artist Dolly Parton with song Here You Come Again
# Empty URL, skipping
# No results for artist Bachman-Turner Overdrive with song You Ain't Seen Nothing Yet
# Empty URL, skipping
# No results for artist Starland Vocal Band with song Afternoon Delight
# Empty URL, skipping
# No results for artist Barry Manilow with song Mandy
# Empty URL, skipping
# No results for artist Elton John with song Bennie And The Jets
# Empty URL, skipping
# No results for artist The Hollies with song He Ain't Heavy He's My Brother
# Empty URL, skipping
# No results for artist The Doobie Brothers with song Long Train Runnin'
# Empty URL, skipping
# No results for artist Chicago with song If You Leave Me Now
# Empty URL, skipping
# No results for artist Hot Chocolate with song You Sexy Thing
# Empty URL, skipping
# No results for artist America with song Ventura Highway
# Empty URL, skipping
# No results for artist Carpenters with song Top Of The World
# Empty URL, skipping
# No results for artist Bee Gees with song Jive Talkin'
# Empty URL, skipping
# No results for artist Exile with song Kiss You All Over
# Empty URL, skipping
# No results for artist ABBA with song Fernando
# Empty URL, skipping
# No results for artist The Boomtown Rats with song I Don't Like Mondays
# Empty URL, skipping
# No results for artist Creedence Clearwater Revival with song Who'll Stop The Rain
# Empty URL, skipping
# No results for artist Fleetwood Mac with song Never Going Back Again
# Empty URL, skipping
# No results for artist Stevie Wonder with song Superstition
# Empty URL, skipping
# No results for artist Yusuf / Cat Stevens with song Morning Has Broken
# Empty URL, skipping
# No results for artist Bob Seger with song Still The Same
# Empty URL, skipping
# No results for artist Bill Withers with song Lovely Day
# Empty URL, skipping
# No results for artist Meat Loaf with song Two Out of Three Ain't Bad
# Empty URL, skipping
# No results for artist Crystal Gayle with song Don't It Make My Brown Eyes Blue
# Empty URL, skipping
# No results for artist ABBA with song Waterloo
# Empty URL, skipping
# No results for artist Frankie Valli with song Grease
# Empty URL, skipping
# No results for artist Stevie Wonder with song Sir Duke
# Empty URL, skipping
# No results for artist Fleetwood Mac with song Landslide
# Empty URL, skipping
# No results for artist The Knack with song My Sharona
# Empty URL, skipping
# No results for artist Bill Withers with song Lean on Me
# Empty URL, skipping
# No results for artist The O''Jays with song Love Train
# Empty URL, skipping
# No results for artist Electric Light Orchestra with song Don't Bring Me Down
# Empty URL, skipping
# No results for artist Todd Rundgren with song I Saw the Light
# Empty URL, skipping
# No results for artist Dolly Parton with song I Will Always Love You
# Empty URL, skipping
# No results for artist Suzi Quatro with song Stumblin' In
# Empty URL, skipping
# No results for artist Bill Withers with song Ain't No Sunshine
# Empty URL, skipping
# No results for artist Leo Sayer with song You Make Me Feel Like Dancing
# Empty URL, skipping
# No results for artist Derek and The Dominos with song Layla
# Empty URL, skipping
# No results for artist T. Rex with song Get It On
# Empty URL, skipping
# No results for artist Meat Loaf with song You Took The Words Right Out of My Mouth
# Empty URL, skipping
# No results for artist James Taylor with song Your Smiling Face
# Empty URL, skipping
# No results for artist Stevie Wonder with song We Can Work It Out
# Empty URL, skipping
# No results for artist Steely Dan with song Reelin' In The Years
# Empty URL, skipping
# No results for artist The Rolling Stones with song Wild Horses
# Empty URL, skipping
# No results for artist Cliff Richard with song We Don't Talk Anymore
# Empty URL, skipping
# No results for artist Supertramp with song The Logical Song
# Empty URL, skipping
# No results for artist Sister Sledge with song We Are Family
# Empty URL, skipping
# No results for artist Barry White with song You're The First, The Last, My Everything
# Empty URL, skipping
# No results for artist Fleetwood Mac with song Dreams
# Empty URL, skipping
# No results for artist England Dan and John Ford Coley with song I'd Really Love to See You Tonight
# Empty URL, skipping
# No results for artist Stevie Wonder with song I Wish
# Empty URL, skipping
# No results for artist Neil Young with song Heart of Gold
# Empty URL, skipping
# No results for artist Rod Stewart with song I Don't Want to Talk About It
# Empty URL, skipping
# No results for artist Billy Ocean with song Love Really Hurts Without You
# Empty URL, skipping
# No results for artist ABBA with song SOS
# Empty URL, skipping
# No results for artist Carpenters with song Please Mr. Postman
# Empty URL, skipping
# No results for artist Elton John with song Are You Ready For Love?
# Empty URL, skipping
# No results for artist Steely Dan with song Do It Again
# Empty URL, skipping
# No results for artist Stevie Wonder with song Isn't She Lovely
# Empty URL, skipping
# No results for artist Seals and Crofts with song Summer Breeze
# Empty URL, skipping
# No results for artist Eagles with song One of These Nights
# Empty URL, skipping
# No results for artist The Emotions with song Best of My Love
# Empty URL, skipping
# No results for artist Patti Smith with song Because the Night
# Empty URL, skipping
# No results for artist Three Dog Night with song Joy To The World
# Empty URL, skipping
# No results for artist Jimmy Cliff with song You Can Get It If You Really Want
# Empty URL, skipping
# No results for artist Lou Reed with song Walk On the Wild Side
# Empty URL, skipping
# No results for artist The Real Thing with song You To Me Are Everything
# Empty URL, skipping
# No results for artist Creedence Clearwater Revival with song Have You Ever Seen The Rain
# Empty URL, skipping
# No results for artist Bob Dylan with song Knockin' On Heaven's Door
# Empty URL, skipping
# No results for artist The Beatles with song Let It Be
# Empty URL, skipping
# No results for artist Barbra Streisand with song The Way We Were
# Empty URL, skipping
# No results for artist Rod Stewart with song Sailing
# Empty URL, skipping
# No results for artist Commodores with song Three Times A Lady
# Empty URL, skipping
# No results for artist John Paul Young with song Love Is In The Air
# Empty URL, skipping
# No results for artist Bette Midler with song The Rose
# Empty URL, skipping
# No results for artist Marvin Gaye with song What's Going On
# Empty URL, skipping
# No results for artist Al Green with song Let's Stay Together
# Empty URL, skipping
# No results for artist Jimmy Cliff with song The Harder They Come
# Empty URL, skipping
# No results for artist Tom Petty and the Heartbreakers with song American Girl
# Empty URL, skipping
# No results for artist Eric Clapton with song I Shot The Sheriff
# Empty URL, skipping
# No results for artist George Harrison with song My Sweet Lord
# Empty URL, skipping
# Track ID not available
# No results for artist a-ha with song Take on Me
# Empty URL, skipping
# No results for artist Phil Collins with song A Groovy Kind Of Love
# Empty URL, skipping
# No results for artist Cyndi Lauper with song Time After Time
# Empty URL, skipping
# No results for artist Tina Turner with song What's Love Got to Do with It
# Empty URL, skipping
# No results for artist Bruce Springsteen with song Dancing In the Dark
# Empty URL, skipping
# No results for artist The Police with song Every Breath You Take
# Empty URL, skipping
# No results for artist Culture Club with song Karma Chameleon
# Empty URL, skipping
# No results for artist Michael Jackson with song Billie Jean
# Empty URL, skipping
# No results for artist Whitney Houston with song I Wanna Dance with Somebody
# Empty URL, skipping
# No results for artist Bryan Adams with song Summer Of '69
# Empty URL, skipping
# No results for artist Earth, Wind and Fire with song Let's Groove
# Empty URL, skipping
# No results for artist Survivor with song Eye of the Tiger
# Empty URL, skipping
# No results for artist Tina Turner with song The Best
# Empty URL, skipping
# No results for artist George Michael with song Faith
# Empty URL, skipping
# No results for artist Phil Collins with song You Can't Hurry Love
# Empty URL, skipping
# No results for artist U2 with song I Still Haven't Found What I'm Looking For
# Empty URL, skipping
# No results for artist Queen with song Crazy Little Thing Called Love
# Empty URL, skipping
# No results for artist Dolly Parton with song Islands in the Stream
# Empty URL, skipping
# No results for artist Simple Minds with song Don't You
# Empty URL, skipping
# No results for artist Eric Carmen with song Hungry Eyes
# Empty URL, skipping
# No results for artist Lionel Richie with song Dancing On The Ceiling
# Empty URL, skipping
# No results for artist Elton John with song I'm Still Standing
# Empty URL, skipping
# No results for artist George Harrison with song Got My Mind Set On You
# Empty URL, skipping
# No results for artist Huey Lewis and The News with song Stuck With You
# Empty URL, skipping
# No results for artist Erasure with song A Little Respect
# Empty URL, skipping
# No results for artist Starship with song Nothing's Gonna Stop Us Now
# Empty URL, skipping
# No results for artist Journey with song Don't Stop Believin'
# Empty URL, skipping
# No results for artist Katrina and The Waves with song Walking On Sunshine
# Empty URL, skipping
# No results for artist Huey Lewis and The News with song The Power Of Love
# Empty URL, skipping
# No results for artist The Police with song Every Little Thing She Does Is Magic
# Empty URL, skipping
# No results for artist Dire Straits with song Walk Of Life
# Empty URL, skipping
# No results for artist Bruce Springsteen with song Hungry Heart
# Empty URL, skipping
# No results for artist Genesis with song Invisible Touch
# Empty URL, skipping
# No results for artist George Michael with song I Knew You Were Waiting
# Empty URL, skipping
# No results for artist The Bangles with song Manic Monday
# Empty URL, skipping
# No results for artist Billy Joel with song Uptown Girl
# Empty URL, skipping
# No results for artist Bill Medley with song (I've Had) The Time of My Life
# Empty URL, skipping
# No results for artist Cher with song If I Could Turn Back Time
# Empty URL, skipping
# No results for artist Robert Palmer with song Addicted To Love
# Empty URL, skipping
# No results for artist Kenny Loggins with song Footloose
# Empty URL, skipping
# No results for artist Roxette with song The Look
# Empty URL, skipping
# No results for artist Fleetwood Mac with song Everywhere
# Empty URL, skipping
# No results for artist Don Henley with song The Boys Of Summer
# Empty URL, skipping
# No results for artist The Pointer Sisters with song Jump
# Empty URL, skipping
# No results for artist TOTO with song Rosanna
# Empty URL, skipping
# No results for artist Lionel Richie with song All Night Long
# Empty URL, skipping
# No results for artist Wham! with song Wake Me Up Before You Go-Go
# Empty URL, skipping
# No results for artist Elton John with song I Guess That's Why They Call It The Blues
# Empty URL, skipping
# No results for artist Tina Turner with song We Don't Need Another Hero
# Empty URL, skipping
# No results for artist Phil Collins with song Against All Odds
# Empty URL, skipping
# No results for artist Pet Shop Boys with song Always on My Mind
# Empty URL, skipping
# No results for artist ABBA with song The Winner Takes It All
# Empty URL, skipping
# No results for artist Steve Winwood with song Valerie
# Empty URL, skipping
# No results for artist Philip Bailey with song Easy Lover
# Empty URL, skipping
# No results for artist John Parr with song St. Elmos Fire
# Empty URL, skipping
# No results for artist Fleetwood Mac with song Little Lies
# Empty URL, skipping
# No results for artist Cyndi Lauper with song Girls Just Want to Have Fun
# Empty URL, skipping
# No results for artist Bruce Springsteen with song Glory Days
# Empty URL, skipping
# No results for artist Paul Simon with song You Can Call Me Al
# Empty URL, skipping
# No results for artist Elton John with song Nikita
# Empty URL, skipping
# No results for artist U2 with song Pride
# Empty URL, skipping
# No results for artist Mike and The Mechanics with song The Living Years
# Empty URL, skipping
# No results for artist Bruce Hornsby with song The Way It Is
# Empty URL, skipping
# No results for artist Pretenders with song Don't Get Me Wrong
# Empty URL, skipping
# No results for artist Madonna with song Papa Don't Preach
# Empty URL, skipping
# No results for artist Starship with song We Built This City
# Empty URL, skipping
# No results for artist John Farnham with song You're the Voice
# Empty URL, skipping
# No results for artist Climie Fisher with song Love Changes
# Empty URL, skipping
# No results for artist Belinda Carlisle with song Heaven Is a Place on Earth
# Empty URL, skipping
# No results for artist Dan Hartman with song I Can Dream About You
# Empty URL, skipping
# No results for artist Madonna with song Like a Prayer
# Empty URL, skipping
# No results for artist Laura Branigan with song Gloria
# Empty URL, skipping
# No results for artist The Communards with song Don't Leave Me This Way
# Empty URL, skipping
# No results for artist Texas with song I Don't Want A Lover
# Empty URL, skipping
# No results for artist Bon Jovi with song Livin' On A Prayer
# Empty URL, skipping
# No results for artist Billy Ocean with song Get Outta My Dreams, Get Into My Car
# Empty URL, skipping
# No results for artist Madonna with song Holiday
# Empty URL, skipping
# No results for artist Glenn Frey with song The Heat Is On
# Empty URL, skipping
# No results for artist The Human League with song Don't You Want Me
# Empty URL, skipping
# No results for artist Whitesnake with song Here I Go Again
# Empty URL, skipping
# No results for artist Alannah Myles with song Black Velvet
# Empty URL, skipping
# No results for artist Michael Jackson with song The Way You Make Me Feel
# Empty URL, skipping
# No results for artist ABBA with song Super Trouper
# Empty URL, skipping
# No results for artist INXS with song Need You Tonight
# Empty URL, skipping
# No results for artist Billy Ocean with song When the Going Gets Tough, The Tough Get Going
# Empty URL, skipping
# No results for artist Queen with song A Kind Of Magic
# Empty URL, skipping
# No results for artist Fine Young Cannibals with song She Drives Me Crazy
# Empty URL, skipping
# No results for artist The Rolling Stones with song Start Me Up
# Empty URL, skipping
# No results for artist Heart with song Alone
# Empty URL, skipping
# No results for artist Bryan Adams with song Run To You
# Empty URL, skipping
# No results for artist Prince with song Purple Rain
# Empty URL, skipping
# No results for artist TOTO with song Africa
# Empty URL, skipping
# No results for artist Queen with song Under Pressure
# Empty URL, skipping
# No results for artist Crowded House with song Don't Dream It's Over
# Empty URL, skipping
# No results for artist The Waterboys with song The Whole Of The Moon
# Empty URL, skipping
# No results for artist The Proclaimers with song I'm Gonna Be
# Empty URL, skipping
# No results for artist U2 with song With Or Without You
# Empty URL, skipping
# No results for artist Bonnie Tyler with song Total Eclipse of the Heart
# Empty URL, skipping
# No results for artist Dolly Parton with song 9 to 5
# Empty URL, skipping
# No results for artist Joe Cocker with song Up Where We Belong
# Empty URL, skipping
# No results for artist Kim Carnes with song Bette Davis Eyes
# Empty URL, skipping
# No results for artist Foreigner with song I Want to Know What Love Is
# Empty URL, skipping
# No results for artist INXS with song New Sensation
# Empty URL, skipping
# No results for artist The Bangles with song Eternal Flame
# Empty URL, skipping
# No results for artist Steve Winwood with song Higher Love
# Empty URL, skipping
# No results for artist Tina Turner with song Private Dancer
# Empty URL, skipping
# No results for artist Irene Cara with song Fame
# Empty URL, skipping
# No results for artist Peter Cetera with song Glory of Love
# Empty URL, skipping
# No results for artist The B-52''s with song Love Shack
# Empty URL, skipping
# No results for artist Bryan Adams with song Heaven
# Empty URL, skipping
# No results for artist U2 with song Where The Streets Have No Name
# Empty URL, skipping
# No results for artist Danny Wilson with song Mary's Prayer
# Empty URL, skipping
# No results for artist Dionne Warwick with song That's What Friends Are For
# Empty URL, skipping
# No results for artist REO Speedwagon with song Can't Fight This Feeling
# Empty URL, skipping
# No results for artist INXS with song Never Tear Us Apart
# Empty URL, skipping
# No results for artist Irene Cara with song Flashdance...What a Feeling
# Empty URL, skipping
# No results for artist UB40 with song I Got You Babe
# Empty URL, skipping
# No results for artist Christopher Cross with song All Right
# Empty URL, skipping
# No results for artist Paul McCartney with song Ebony and Ivory
# Empty URL, skipping
# No results for artist Michael Jackson with song Man in the Mirror
# Empty URL, skipping
# No results for artist Peter Gabriel with song Sledgehammer
# Empty URL, skipping
# No results for artist Roy Orbison with song You Got It
# Empty URL, skipping
# No results for artist Whitney Houston with song How Will I Know
# Empty URL, skipping
# No results for artist Bruce Springsteen with song Born in the U.S.A.
# Empty URL, skipping
# No results for artist The Human League with song Together In Electric Dreams
# Empty URL, skipping
# No results for artist REO Speedwagon with song Keep on Loving You
# Empty URL, skipping
# No results for artist Depeche Mode with song Just Can't Get Enough
# Empty URL, skipping
# No results for artist Eurythmics with song Thorn in My Side
# Empty URL, skipping
# No results for artist The Police with song De Do Do Do, De Da Da Da
# Empty URL, skipping
# No results for artist Wet Wet Wet with song Sweet Little Mystery
# Empty URL, skipping
# No results for artist TOTO with song Stop Loving You
# Empty URL, skipping
# No results for artist Bryan Adams with song It's Only Love
# Empty URL, skipping
# No results for artist David Bowie with song Let's Dance
# Empty URL, skipping
# No results for artist Kool and The Gang with song Celebration
# Empty URL, skipping
# No results for artist Elton John with song Sacrifice
# Empty URL, skipping
# No results for artist Roxette with song Listen To Your Heart
# Empty URL, skipping
# No results for artist Van Halen with song Jump
# Empty URL, skipping
# No results for artist Daryl Hall and John Oates with song Maneater
# Empty URL, skipping
# No results for artist Tom Petty with song Free Fallin'
# Empty URL, skipping
# No results for artist The Pointer Sisters with song I'm So Excited
# Empty URL, skipping
# No results for artist Rod Stewart with song Baby Jane
# Empty URL, skipping
# No results for artist John Waite with song Missing You
# Empty URL, skipping
# No results for artist Simply Red with song If You Don't Know Me by Now
# Empty URL, skipping
# No results for artist Cutting Crew with song (I Just) Died In Your Arms
# Empty URL, skipping
# No results for artist Christopher Cross with song Arthur's Theme
# Empty URL, skipping
# No results for artist Prince with song Kiss
# Empty URL, skipping
# No results for artist Marillion with song Kayleigh
# Empty URL, skipping
# No results for artist Cyndi Lauper with song True Colors
# Empty URL, skipping
# No results for artist Eurythmics with song There Must Be an Angel
# Empty URL, skipping
# No results for artist Queen with song I Want To Break Free
# Empty URL, skipping
# Track ID not available
# No results for artist Backstreet Boys with song I Want It That Way
# Empty URL, skipping
# No results for artist Britney Spears with song ...Baby One More Time
# Empty URL, skipping
# No results for artist Spice Girls with song Wannabe
# Empty URL, skipping
# No results for artist Dr. Dre with song Still D.R.E.
# Empty URL, skipping
# No results for artist Oasis with song Wonderwall
# Empty URL, skipping
# No results for artist Coolio with song Gangsta's Paradise
# Empty URL, skipping
# No results for artist Sixpence None The Richer with song Kiss Me
# Empty URL, skipping
# No results for artist 2Pac with song California Love
# Empty URL, skipping
# No results for artist Natalie Imbruglia with song Torn
# Empty URL, skipping
# No results for artist Cher with song Believe
# Empty URL, skipping
# No results for artist Janet Jackson with song Together Again
# Empty URL, skipping
# No results for artist Céline Dion with song It's All Coming Back to Me Now
# Empty URL, skipping
# No results for artist Spice Girls with song Stop
# Empty URL, skipping
# No results for artist Wilson Phillips with song Hold On
# Empty URL, skipping
# No results for artist Bryan Adams with song When You're Gone
# Empty URL, skipping
# No results for artist Faith Hill with song This Kiss
# Empty URL, skipping
# No results for artist Shania Twain with song Man! I Feel Like A Woman!
# Empty URL, skipping
# No results for artist Cher with song Walking in Memphis
# Empty URL, skipping
# No results for artist Hanson with song MMMBop
# Empty URL, skipping
# No results for artist Annie Lennox with song Walking on Broken Glass
# Empty URL, skipping
# No results for artist George Michael with song Freedom! '90
# Empty URL, skipping
# No results for artist Mariah Carey with song Fantasy
# Empty URL, skipping
# No results for artist Alanis Morissette with song Ironic
# Empty URL, skipping
# No results for artist Shania Twain with song That Don't Impress Me Much
# Empty URL, skipping
# No results for artist Amy Grant with song Baby, Baby
# Empty URL, skipping
# No results for artist Boyzone with song Picture Of You
# Empty URL, skipping
# No results for artist Take That with song Back for Good
# Empty URL, skipping
# No results for artist Mr. Big with song To Be With You
# Empty URL, skipping
# No results for artist Shania Twain with song You're Still The One
# Empty URL, skipping
# No results for artist Meat Loaf with song I'd Do Anything For Love
# Empty URL, skipping
# No results for artist The Rembrandts with song I'll Be There for You
# Empty URL, skipping
# No results for artist Joshua Kadison with song Jessie
# Empty URL, skipping
# No results for artist Michael Jackson with song Black or White
# Empty URL, skipping
# No results for artist Go West with song The King of Wishful Thinking
# Empty URL, skipping
# No results for artist George Michael with song Don't Let the Sun Go Down on Me
# Empty URL, skipping
# No results for artist Phil Collins with song You'll Be In My Heart
# Empty URL, skipping
# No results for artist Backstreet Boys with song As Long as You Love Me
# Empty URL, skipping
# No results for artist Donna Lewis with song I Love You Always Forever
# Empty URL, skipping
# No results for artist Hootie and The Blowfish with song Only Wanna Be with You
# Empty URL, skipping
# No results for artist Mariah Carey with song Always Be My Baby
# Empty URL, skipping
# No results for artist Savage Garden with song Truly Madly Deeply
# Empty URL, skipping
# No results for artist Ronan Keating with song When You Say Nothing At All
# Empty URL, skipping
# No results for artist Roxette with song Fading Like A Flower
# Empty URL, skipping
# No results for artist Céline Dion with song Because You Loved Me
# Empty URL, skipping
# No results for artist Cher with song The Shoop Shoop Song
# Empty URL, skipping
# No results for artist M People with song Moving on Up
# Empty URL, skipping
# No results for artist Ace of Base with song The Sign
# Empty URL, skipping
# No results for artist Backstreet Boys with song Everybody
# Empty URL, skipping
# No results for artist Roxette with song Joyride
# Empty URL, skipping
# No results for artist Deep Blue Something with song Breakfast At Tiffany's
# Empty URL, skipping
# No results for artist Des''ree with song You Gotta Be
# Empty URL, skipping
# No results for artist Britney Spears with song Sometimes
# Empty URL, skipping
# No results for artist Elton John with song Circle of Life
# Empty URL, skipping

# %%
sonic_anger_indices
# Out:
# {'50s': 0.39431420569370135,
#  '60s': 0.4148219016720213,
#  '70s': 0.43369555999122505,
#  '80s': 0.46928879219526437,
#  '90s': 0.5375934388502596,
#  '100s': 0.5246415353695427,
#  '110s': 0.5703397090563421}
